# %% [markdown]
# <a href="https://colab.research.google.com/github/cjsantacruz325-sys/cs1q4_practicaltest/blob/main/cs1q4_practicaltest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Name = input("Please input your name here ")
scoreattempts = int(input("How many quiz scores would you like to enter? "))

quiz_scores_list = []
attempts = 0
while attempts < scoreattempts:
    score = int(input("Please input your quiz scores "))
    quiz_scores_list.append(score)
    attempts += 1

total = __builtins__.sum(quiz_scores_list)
print("The total is", total)
print("The average score is ", total/scoreattempts)

if total/scoreattempts >=75:
  print("Passed")
elif total/scoreattempts <75:
  print("Failed")
# Out:
# Please input your name here me
# How many quiz scores would you like to enter? 2
# Please input your quiz scores 90
# Please input your quiz scores 90
# The total is 180
# The average score is  90.0
# Passed
